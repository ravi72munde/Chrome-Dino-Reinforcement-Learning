# %%
import numpy as np
from PIL import ImageGrab
from PIL import Image
import cv2
import io
import time
# %matplotlib inline 
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (15, 9)
import seaborn as sns
import pandas as pd
import numpy as np

# %%
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
game_url = "game/dino.html"
chrome_driver_path = "../chromedriver.exe"
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.set_window_size(200, 300)
        self._driver.get(os.path.abspath(game_url))
        if custom_config:
            self._driver.execute_script("Runner.config.ACCELERATION=0")
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
#         self._driver.refresh()
#         self.press_up()
#         time.sleep(0.5)
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def press_down(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_DOWN)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array)
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game):
        self._game = game;
        self.jump();
        time.sleep(.5)
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
#processing image as required
def process_img(image):
    #game is already in grey scale canvas, canny to get only edges and reduce unwanted objects(clouds)
#     image = cv2.Canny(image, threshold1 = 100, threshold2 = 200)
#     image = image[10:140,0:200] #img[y:y+h, x:x+w]
#     image = resized_image = cv2.resize(image, (80, 80)) 
    image = cv2.resize(image, (0,0), fx = 0.15, fy = 0.10)
    image = image[2:38,10:50] #img[y:y+h, x:x+w]
    image = cv2.Canny(image, threshold1 = 200, threshold2 = 200)
    return  image

# %%
def grab_screen(_driver = None):
    screen =  np.array(ImageGrab.grab(bbox=(0,180,400,400)))
    image = process_img(screen)
    if _driver!=None:
        image = _driver.get_screenshot_as_png()
    return image

# %%
# print(grab_screen().shape)
# game = Game()
# dino = DinoAgent(game)
# last_time = time.time()
# while(True):
    
# # #     print('loop took {} seconds'.format(time.time()-last_time))
# # #     last_time = time.time()
# # #     cv2.imwrite("./img_data/dino"+str(time())+".jpg",image)
# # #     dino.duck()
# #     #exit on q pres
# # #     print('{0} {1} '.format(r_t,end_t))
# # #     cv2.imshow('window',game.grab_screen())
    
#     image = grab_screen()
#     cv2.imshow('window',image)
#     print(image.shape[0])
# #     cv2.destroyAllWindows()

# # #     from matplotlib import pyplot as plt
# # #     plt.imshow(image)
# # #     plt.title('my picture')
# # #     plt.show()

# # #     grab_screen()
# #     if(dino.is_crashed()):
# #         #jumping starts the game again if dino has crashed
# # #         temp = (game.get_score())
# #         game.restart()
#     if (cv2.waitKey(25) & 0xFF == ord('q')):
#         cv2.destroyAllWindows()
#         game.end()
# #         cv2.imwrite('dino.jpg',image)
#         break

# %%
import pickle
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.8 # decay rate of past observations original 0.99
OBSERVATION = 20000. # timesteps to observe before training
EXPLORE = 50000 #300000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 4
LEARNING_RATE = 1e-4

# %%
"""initial variable caching, done only once"""
# save_obj(FINAL_EPSILON,"epsilon")
# t = 0
# save_obj(t,"time")
# D = deque()
# save_obj(D,"D")

# %%
img_rows , img_cols = 40,20
img_channels = 4 #We stack 4 frames

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Convolution2D(32, 8, 8, subsample=(4, 4), border_mode='same',input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 4, 4, subsample=(2, 2), border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3, subsample=(1, 1), border_mode='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    print("We finish building the model")
    return model

# %%
def trainNetwork(model,game_state,observe=False):
    # open up a game state to communicate with emulator
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #deque()
    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 
    x_t, r_0, terminal = game_state.get_state(do_nothing)
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    

    #In Keras, need to reshape
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*80*80*4
    initial_state = s_t

    if observe :#args['mode'] == 'Run':
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon")#FINAL_EPSILON #INITIAL_EPSILON
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time")
    while (True):
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0
        a_t = np.zeros([ACTIONS])
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0:
            if  random.random() <= epsilon:
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else:
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)
                action_index = max_Q
                a_t[action_index] = 1
        #We reduced the epsilon gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE #update to original asap

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('loop took {} seconds'.format(time.time()-last_time))
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x80x80x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3)

        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]
                state_t1 = minibatch[i][3]
                terminal = minibatch[i][4]
                # if terminated, only equals reward

                inputs[i:i + 1] = state_t    #I saved down s_t

                targets[i] = model.predict(state_t)  # Hitting each buttom probability
                Q_sa = model.predict(state_t1)
                
                if terminal:
                    targets[i, action_t] = reward_t
                else:
                    temp_q_max = np.max(Q_sa)
                    targets[i, action_t] = reward_t + GAMMA * temp_q_max
            # targets2 = normalize(targets)
            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
        else:
            #artificial time delay as training done with this delay
            loss_df.loc[len(loss_df)] = 0
            time.sleep(0.15)
        s_t = initial_state if terminal else s_t1
        t = t + 1
        
        # save progress every 10000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
loss_df = pd.read_csv("./objects/loss_df.csv")
scores_df = pd.read_csv("./objects/scores_df.csv")
actions_df = pd.read_csv("./objects/actions_df.csv")
q_max_df = pd.read_csv("./objects/q_values.csv")

# %%
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)
    model = buildmodel()
    trainNetwork(model,game_state,observe=observe)

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img()
        self._display.__next__()
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1]
        reward = 0.1
        is_over = False
        if actions[1] == 1:
            self._agent.jump()

        image = grab_screen()
        self._display.send(image)

        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = self._game.get_score()
            self._game.restart()
            reward = -5
            is_over = True
        return image, reward, is_over

# %%
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD , Adam
import tensorflow as tf
from keras.callbacks import TensorBoard
from collections import deque
import random
import json

# %%
def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
#         cv2.imwrite("screenshot"+str(frame)+".png",screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
playGame(observe=False);
# Out:
# Now we build the model
# We finish building the model
# C:\Users\ravi7\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 8), input_shape=(20, 40, 4..., strides=(4, 4), padding="same")`
#   after removing the cwd from sys.path.
# C:\Users\ravi7\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), strides=(2, 2), padding="same")`
#
# C:\Users\ravi7\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), strides=(1, 1), padding="same")`
# loop took 1.8045954704284668 seconds
# TIMESTEP 362001 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.787832 / Loss  0.366797655821
# loop took 1.1771795749664307 seconds
# TIMESTEP 362002 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.229741 / Loss  0.145929902792
# loop took 0.3058488368988037 seconds
# TIMESTEP 362003 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.00131106 / Loss  0.0668866932392
# loop took 0.29804444313049316 seconds
# TIMESTEP 362004 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.900846 / Loss  0.0517612807453
# loop took 0.29641056060791016 seconds
# TIMESTEP 362005 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.892021 / Loss  0.342787533998
# loop took 0.28273797035217285 seconds
# TIMESTEP 362006 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0.0979812 / Loss  0.169922381639
# loop took 0.8720448017120361 seconds
# TIMESTEP 362007 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -5 / Q_MAX  0.106955 / Loss  0.0675116851926
# loop took 0.28275179862976074 seconds
# TIMESTEP 362008 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.330523 / Loss  0.410424441099
# loop took 0.31674647331237793 seconds
# TIMESTEP 362009 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  0.137644 / Loss  0.53804987669
# loop took 0.3423919677734375 seconds
# TIMESTEP 362010 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -5.21535 / Loss  0.485997200012
# loop took 0.30990099906921387 seconds
# TIMESTEP 362011 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.582236 / Loss  0.336565345526
# loop took 0.34403514862060547 seconds
# TIMESTEP 362012 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.075634 / Loss  0.42101162672
# loop took 0.34187912940979004 seconds
# TIMESTEP 362013 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.37604 / Loss  0.652628183365
# loop took 0.33496832847595215 seconds
# TIMESTEP 362014 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.474404 / Loss  0.0393387228251
# loop took 0.339815616607666 seconds
# TIMESTEP 362015 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.878109 / Loss  0.350681900978
# loop took 0.31383657455444336 seconds
# TIMESTEP 362016 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.557269 / Loss  0.330379098654
# loop took 0.38001418113708496 seconds
# TIMESTEP 362017 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.235482 / Loss  0.262157738209
# loop took 0.33417415618896484 seconds
# TIMESTEP 362018 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.394643 / Loss  0.0300418939441
# loop took 0.8914017677307129 seconds
# TIMESTEP 362019 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -5 / Q_MAX  -0.24572 / Loss  0.213348373771
# loop took 0.3158416748046875 seconds
# TIMESTEP 362020 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.248806 / Loss  0.31940060854
# loop took 0.3229515552520752 seconds
# TIMESTEP 362021 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.7603 / Loss  0.330127507448
# loop took 0.31343889236450195 seconds
# TIMESTEP 362022 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0.0273576 / Loss  0.268534660339
# loop took 0.33196043968200684 seconds
# TIMESTEP 362023 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.605478 / Loss  0.133382186294
# loop took 0.34079909324645996 seconds
# TIMESTEP 362024 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.698547 / Loss  0.460044711828
# loop took 0.36248779296875 seconds
# TIMESTEP 362025 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.64671 / Loss  0.123699016869
# loop took 0.34599995613098145 seconds
# TIMESTEP 362026 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0.0842528 / Loss  0.740285515785
# loop took 0.36619019508361816 seconds
# TIMESTEP 362027 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.133579 / Loss  0.385881125927
# loop took 0.33556509017944336 seconds
# TIMESTEP 362028 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0.00621343 / Loss  0.246143713593
# loop took 0.3656458854675293 seconds
# TIMESTEP 362029 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.189562 / Loss  0.615439355373
# loop took 0.33092522621154785 seconds
# TIMESTEP 362030 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.82979 / Loss  0.394620895386
# loop took 0.908289909362793 seconds
# TIMESTEP 362031 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -5 / Q_MAX  -1.74137 / Loss  0.356492549181
# loop took 0.32724642753601074 seconds
# TIMESTEP 362032 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -3.55608 / Loss  0.380893200636
# loop took 0.3555426597595215 seconds
# TIMESTEP 362033 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  0.104678 / Loss  0.471854388714
# loop took 0.3118290901184082 seconds
# TIMESTEP 362034 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.384841 / Loss  0.317003637552
# loop took 0.31659531593322754 seconds
# TIMESTEP 362035 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.11179 / Loss  0.728564679623
# loop took 0.34893321990966797 seconds
# TIMESTEP 362036 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.20052 / Loss  0.423027724028
# loop took 0.354811429977417 seconds
# TIMESTEP 362037 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.352651 / Loss  0.219711080194
# loop took 0.31504225730895996 seconds
# TIMESTEP 362038 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.342459 / Loss  0.373496860266
# loop took 0.3238801956176758 seconds
# TIMESTEP 362039 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.29794 / Loss  0.179715231061
# loop took 0.32692956924438477 seconds
# TIMESTEP 362040 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.405234 / Loss  0.598127067089
# loop took 0.32642269134521484 seconds
# TIMESTEP 362041 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -4.86235 / Loss  0.48453977704
# loop took 0.29783010482788086 seconds
# TIMESTEP 362042 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -5.08355 / Loss  0.463900923729
# loop took 0.8987400531768799 seconds
# TIMESTEP 362043 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -5 / Q_MAX  -0.67866 / Loss  0.385592222214
# loop took 0.3348836898803711 seconds
# TIMESTEP 362044 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -4.60365 / Loss  0.503829240799
# loop took 0.34496283531188965 seconds
# TIMESTEP 362045 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.172153 / Loss  0.969733417034
# loop took 0.3440384864807129 seconds
# TIMESTEP 362046 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.77464 / Loss  0.149248898029
# loop took 0.3451957702636719 seconds
# TIMESTEP 362047 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0.114448 / Loss  0.218475982547
# loop took 0.34850645065307617 seconds
# TIMESTEP 362048 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.1864 / Loss  0.122543811798
# loop took 0.36713409423828125 seconds
# TIMESTEP 362049 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.58195 / Loss  0.1981138587
# loop took 0.3499314785003662 seconds
# TIMESTEP 362050 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.72377 / Loss  0.543070435524
# loop took 0.4772677421569824 seconds
# TIMESTEP 362051 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.6135 / Loss  0.285491347313
# loop took 0.3314223289489746 seconds
# TIMESTEP 362052 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.78063 / Loss  0.704236388206
# loop took 0.3178997039794922 seconds
# TIMESTEP 362053 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  0.0614772 / Loss  0.149751141667
# loop took 0.31093668937683105 seconds
# TIMESTEP 362054 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.428702 / Loss  0.0962767079473
# loop took 0.8790087699890137 seconds
# TIMESTEP 362055 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -5 / Q_MAX  -1.61794 / Loss  0.153200536966
# loop took 0.30274486541748047 seconds
# TIMESTEP 362056 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.413467 / Loss  0.353804707527
# loop took 0.31238317489624023 seconds
# TIMESTEP 362057 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -5.57372 / Loss  0.300164878368
# loop took 0.31288695335388184 seconds
# TIMESTEP 362058 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.0468645 / Loss  0.165005326271
# loop took 0.3117823600769043 seconds
# TIMESTEP 362059 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.305888 / Loss  0.231403380632
# loop took 0.32706403732299805 seconds
# TIMESTEP 362060 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.330075 / Loss  0.212121844292
# loop took 0.3135251998901367 seconds
# TIMESTEP 362061 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -4.83055 / Loss  0.308359086514
# loop took 0.2947978973388672 seconds
# TIMESTEP 362062 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.168625 / Loss  0.878355503082
# loop took 0.3140108585357666 seconds
# TIMESTEP 362063 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.87236 / Loss  0.620176196098
# loop took 0.32085609436035156 seconds
# TIMESTEP 362064 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0.150451 / Loss  0.305641263723
# loop took 0.334932804107666 seconds
# TIMESTEP 362065 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.37624 / Loss  0.396037220955
# loop took 0.32759952545166016 seconds
# TIMESTEP 362066 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.75715 / Loss  0.494598507881
# loop took 0.33693623542785645 seconds
# TIMESTEP 362067 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -4.68187 / Loss  0.602423250675
# loop took 0.9241876602172852 seconds
# TIMESTEP 362068 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -5 / Q_MAX  -0.408062 / Loss  0.740495026112
# loop took 0.3221471309661865 seconds
# TIMESTEP 362069 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.79896 / Loss  0.51812016964
# loop took 0.3239555358886719 seconds
# TIMESTEP 362070 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.15252 / Loss  0.375873476267
# loop took 0.3178553581237793 seconds
# TIMESTEP 362071 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.31134 / Loss  0.113434121013
# loop took 0.3207523822784424 seconds
# TIMESTEP 362072 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.76958 / Loss  0.625150442123
# loop took 0.3278472423553467 seconds
# TIMESTEP 362073 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.580585 / Loss  0.308893740177
# loop took 0.3179154396057129 seconds
# TIMESTEP 362074 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.0807824 / Loss  0.551416516304
# loop took 0.3275620937347412 seconds
# TIMESTEP 362075 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.00202 / Loss  0.0530179701746
# loop took 0.2928426265716553 seconds
# TIMESTEP 362076 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.320606 / Loss  0.471205890179
# loop took 0.3288571834564209 seconds
# TIMESTEP 362077 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.220735 / Loss  0.0693837925792
# loop took 0.3263061046600342 seconds
# TIMESTEP 362078 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -3.54324 / Loss  0.498663455248
# loop took 0.3170654773712158 seconds
# TIMESTEP 362079 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.53285 / Loss  0.449376553297
# loop took 0.32894420623779297 seconds
# TIMESTEP 362080 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.0352 / Loss  0.474651962519
# loop took 0.9089748859405518 seconds
# TIMESTEP 362081 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -5 / Q_MAX  -0.845326 / Loss  0.524516880512
# loop took 0.33498167991638184 seconds
# TIMESTEP 362082 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.527264 / Loss  0.0576389506459
# loop took 0.29770970344543457 seconds
# TIMESTEP 362083 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.92862 / Loss  0.10142647475
# loop took 0.30970144271850586 seconds
# TIMESTEP 362084 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -4.68387 / Loss  0.321242690086
# loop took 0.3289313316345215 seconds
# TIMESTEP 362085 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.594889 / Loss  0.304151594639
# loop took 0.3132772445678711 seconds
# TIMESTEP 362086 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -5.08851 / Loss  0.211050823331
# loop took 0.29561662673950195 seconds
# TIMESTEP 362087 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.14662 / Loss  0.0652580857277
# loop took 0.3149857521057129 seconds
# TIMESTEP 362088 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.559341 / Loss  0.0596734769642
# loop took 0.32624030113220215 seconds
# TIMESTEP 362089 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.770078 / Loss  0.203073844314
# loop took 0.32787132263183594 seconds
# TIMESTEP 362090 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -5.05343 / Loss  0.152012988925
# loop took 0.31374406814575195 seconds
# TIMESTEP 362091 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.606111 / Loss  0.29532033205
# loop took 0.3579277992248535 seconds
# TIMESTEP 362092 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.13676 / Loss  0.669581830502
# loop took 0.34459638595581055 seconds
# TIMESTEP 362093 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.313475 / Loss  0.836558103561
# loop took 0.3350534439086914 seconds
# TIMESTEP 362094 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.170008 / Loss  0.960879087448
# loop took 0.3048098087310791 seconds
# TIMESTEP 362095 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.519068 / Loss  0.692442834377
# loop took 0.3277742862701416 seconds
# TIMESTEP 362096 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.596643 / Loss  0.6010658741
# loop took 0.8704123497009277 seconds
# TIMESTEP 362097 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -5 / Q_MAX  0.0182722 / Loss  0.519365608692
# loop took 0.3331937789916992 seconds
# TIMESTEP 362098 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -4.77159 / Loss  0.201387315989
# loop took 0.31641578674316406 seconds
# TIMESTEP 362099 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.14283 / Loss  0.339232325554
# loop took 0.47923970222473145 seconds
# TIMESTEP 362100 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.16446 / Loss  0.0850633308291
# loop took 0.29678988456726074 seconds
# TIMESTEP 362101 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.144006 / Loss  0.575945734978
# loop took 0.2807469367980957 seconds
# TIMESTEP 362102 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.018857 / Loss  0.469171762466
# loop took 0.3200962543487549 seconds
# TIMESTEP 362103 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -4.70727 / Loss  0.80167734623
# loop took 0.34795475006103516 seconds
# TIMESTEP 362104 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.41759 / Loss  0.0321939513087
# loop took 0.3313632011413574 seconds
# TIMESTEP 362105 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.0452108 / Loss  0.752145171165
# loop took 0.2968461513519287 seconds
# TIMESTEP 362106 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.634164 / Loss  0.193531125784
# loop took 0.3679814338684082 seconds
# TIMESTEP 362107 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.849817 / Loss  0.186595156789
# loop took 0.3541145324707031 seconds
# TIMESTEP 362108 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.461749 / Loss  0.315207958221
# loop took 0.9164330959320068 seconds
# TIMESTEP 362109 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -5 / Q_MAX  -1.00131 / Loss  0.262278228998
# loop took 0.29787492752075195 seconds
# TIMESTEP 362110 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.09345 / Loss  0.241170704365
# loop took 0.30324578285217285 seconds
# TIMESTEP 362111 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.61063 / Loss  0.59221804142
# loop took 0.2888062000274658 seconds
# TIMESTEP 362112 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.174278 / Loss  0.449293375015
# loop took 0.2987954616546631 seconds
# TIMESTEP 362113 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.295063 / Loss  0.373644828796
# loop took 0.3169059753417969 seconds
# TIMESTEP 362114 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.698614 / Loss  0.31074732542
# loop took 0.3226311206817627 seconds
# TIMESTEP 362115 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.189665 / Loss  0.483084976673
# loop took 0.31383609771728516 seconds
# TIMESTEP 362116 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.861352 / Loss  0.0873245224357
# loop took 0.32607483863830566 seconds
# TIMESTEP 362117 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.627835 / Loss  0.20697657764
# loop took 0.3309316635131836 seconds
# TIMESTEP 362118 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.473164 / Loss  0.178359076381
# loop took 0.3269617557525635 seconds
# TIMESTEP 362119 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.130323 / Loss  0.107958041131
# loop took 0.3268144130706787 seconds
# TIMESTEP 362120 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.114843 / Loss  0.101637296379
# loop took 0.33588647842407227 seconds
# TIMESTEP 362121 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.218249 / Loss  0.436292439699
# loop took 0.32295680046081543 seconds
# TIMESTEP 362122 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.528176 / Loss  0.514139473438
# loop took 0.2937812805175781 seconds
# TIMESTEP 362123 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.0669048 / Loss  0.200042933226
# loop took 0.312896728515625 seconds
# TIMESTEP 362124 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.360661 / Loss  0.329264730215
# loop took 0.3342783451080322 seconds
# TIMESTEP 362125 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.578266 / Loss  0.884655714035
# loop took 0.30605387687683105 seconds
# TIMESTEP 362126 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.536311 / Loss  0.291390419006
# loop took 0.3319268226623535 seconds
# TIMESTEP 362127 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.71827 / Loss  0.272855103016
# loop took 0.3329346179962158 seconds
# TIMESTEP 362128 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.00915 / Loss  0.0919442102313
# loop took 0.925915002822876 seconds
# TIMESTEP 362129 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -5 / Q_MAX  -0.784737 / Loss  0.492821782827
# loop took 0.3318336009979248 seconds
# TIMESTEP 362130 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.38522 / Loss  0.351966828108
# loop took 0.31175684928894043 seconds
# TIMESTEP 362131 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.681223 / Loss  0.380515366793
# loop took 0.3148376941680908 seconds
# TIMESTEP 362132 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -4.41088 / Loss  0.201623618603
# loop took 0.32513928413391113 seconds
# TIMESTEP 362133 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.0831611 / Loss  0.442328512669
# loop took 0.34893250465393066 seconds
# TIMESTEP 362134 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.120953 / Loss  0.773679971695
# loop took 0.32276463508605957 seconds
# TIMESTEP 362135 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.383232 / Loss  0.176325380802
# loop took 0.34610891342163086 seconds
# TIMESTEP 362136 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.592999 / Loss  0.339977949858
# loop took 0.34335803985595703 seconds
# TIMESTEP 362137 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.520947 / Loss  0.617661774158
# loop took 0.32996058464050293 seconds
# TIMESTEP 362138 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.512845 / Loss  0.532239556313
# loop took 0.33917784690856934 seconds
# TIMESTEP 362139 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.602024 / Loss  0.159663438797
# loop took 0.33096957206726074 seconds
# TIMESTEP 362140 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.600602 / Loss  0.245898455381
# loop took 0.9391782283782959 seconds
# TIMESTEP 362141 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -5 / Q_MAX  -4.84316 / Loss  0.51018434763
# loop took 0.292849063873291 seconds
# TIMESTEP 362142 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.779826 / Loss  0.478494226933
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-134-ec9546669aed> in <module>()
# ----> 1 playGame(observe=False);
#
# <ipython-input-93-2255e85230c6> in playGame(observe)
#       4     game_state = Game_sate(dino,game)
#       5     model = buildmodel()
# ----> 6     trainNetwork(model,game_state,observe=observe)
#
# <ipython-input-116-407de15c710e> in trainNetwork(model, game_state, observe)
#      56
#      57         #run the selected action and observed next state and reward
# ---> 58         x_t1, r_t, terminal = game_state.get_state(a_t)
#      59         print('loop took {} seconds'.format(time.time()-last_time))
#      60         last_time = time.time()
#
# <ipython-input-94-002050dc5e55> in get_state(self, actions)
#      13
#      14         image = grab_screen()
# ---> 15         self._display.send(image)
#      16
#      17         if self._agent.is_crashed():
#
# StopIteration:

# %%
def show_plots(realtime = True,t=0):
    fig, axs = plt.subplots(ncols=2,nrows =2)
    loss_df['loss'] = loss_df['loss'].astype('float') 
    loss_df.plot(use_index=True,ax=axs[0,0])
    scores_df.plot(ax=axs[0,1])
    sns.distplot(actions_df,ax=axs[1,0])
#     q_max_df.plot(ax = axs[1,1])
    imgg = fig.canvas.draw()
    graph_img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
    graph_img = graph_img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#     disp = show_img(graphs=True)
#     disp.__next__()
    cv2.imwrite("logs/progress/pg"+str(t)+".png",graph_img) if realtime else 0

# %%
show_plots(realtime=False)
# Out:
# C:\Users\ravi7\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
