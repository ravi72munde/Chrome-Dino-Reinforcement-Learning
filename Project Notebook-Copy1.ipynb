# %%
import numpy as np
from PIL import ImageGrab
from PIL import Image
import cv2
import io
import time
# %matplotlib inline 
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (15, 9)
import seaborn as sns
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint

# %%
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
game_url = "game/dino.html"
chrome_driver_path = "../chromedriver.exe"
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.set_window_size(200, 300)
        self._driver.get(os.path.abspath(game_url))
        if custom_config:
            self._driver.execute_script("Runner.config.ACCELERATION=0")
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
#         self._driver.execute_script("Runner.instance_.config.CLEAR_TIME = "+ str(randint(1, 999)))
        self._driver.execute_script("Runner.instance_.restart()")
#         self._driver.refresh()
#         self.press_up()
        time.sleep(0.25)
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def press_down(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_DOWN)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array)
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game):
        self._game = game;
        self.jump();
        time.sleep(.5)
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
#processing image as required
def process_img(image):
    #game is already in grey scale canvas, canny to get only edges and reduce unwanted objects(clouds)
#     image = cv2.Canny(image, threshold1 = 100, threshold2 = 200)
#     image = image[10:140,0:200] #img[y:y+h, x:x+w]
#     image = resized_image = cv2.resize(image, (80, 80)) 
    image = cv2.resize(image, (0,0), fx = 0.3, fy = 0.25)
    image = image[20:80,0:70] #img[y:y+h, x:x+w]
#     image = cv2.Canny(image, threshold1 = 100, threshold2 = 200)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return  image

# %%
def grab_screen(_driver = None):
    screen =  np.array(ImageGrab.grab(bbox=(40,180,440,400)))
    image = process_img(screen)
    if _driver!=None:
        image = _driver.get_screenshot_as_png()
    return image

# %%
# # # print(grab_screen().shape)
# # # game = Game()
# # # dino = DinoAgent(game)
# # # last_time = time.time()
# while(True):
    
# # # # #     print('loop took {} seconds'.format(time.time()-last_time))
# # # # #     last_time = time.time()
# # # # #     cv2.imwrite("./img_data/dino"+str(time())+".jpg",image)
# # # # #     dino.duck()
# # # #     #exit on q pres
# # # # #     print('{0} {1} '.format(r_t,end_t))
# # # # #     cv2.imshow('window',game.grab_screen())
#     image = grab_screen()
#     cv2.imshow('window',image)
#     print(image.shape)

# # # # #     from matplotlib import pyplot as plt
# # # # #     plt.imshow(image)
# # # # #     plt.title('my picture')
# # # # #     plt.show()

# # # # #     grab_screen()
# # # #     if(dino.is_crashed()):
# # # #         #jumping starts the game again if dino has crashed
# # # # #         temp = (game.get_score())
# # # #         game.restart()
#     if (cv2.waitKey(25) & 0xFF == ord('q')):
#         cv2.destroyAllWindows()
# #         game.end()
# #         cv2.imwrite('dino.jpg',image)
#         break

# %%
import pickle
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 20000. # timesteps to observe before training
EXPLORE = 50000 #300000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4

# %%
# """initial variable caching, done only once"""
# save_obj(INITIAL_EPSILON,"epsilon")
# t = 0
# save_obj(t,"time")
# # D = deque()
# # save_obj(D,"D")

# %%
img_rows , img_cols = 70,35
img_channels = 4 #We stack 4 frames

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
#     Conv2D(32, (8, 8), strides=(4, 4), input_shape=(20, 40, 4..., padding="same")`
    model.add(Conv2D(32, (8, 8), strides=(4, 4), padding='same',input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4), strides=(2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    print("We finish building the model")
    return model

# %%
def trainNetwork(model,game_state,observe=False):
    # open up a game state to communicate with emulator
    last_time = time.time()
    # store the previous observations in replay memory
    D = deque()
    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 
    x_t, r_0, terminal = game_state.get_state(do_nothing)
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    

    #In Keras, need to reshape
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*80*80*4
    initial_state = s_t

    if observe :#args['mode'] == 'Run':
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
#         model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = INITIAL_EPSILON
#         model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = 0
    while (True):
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0
        a_t = np.zeros([ACTIONS])
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0:
            if  random.random() <= epsilon:
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else:
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)
                action_index = max_Q
                a_t[action_index] = 1
        #We reduced the epsilon gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE #update to original asap

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('loop took {} seconds'.format(time.time()-last_time))
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x80x80x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3)
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: # and terminal: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]
                state_t1 = minibatch[i][3]
                terminal = minibatch[i][4]
                # if terminated, only equals reward

                inputs[i:i + 1] = state_t    #I saved down s_t

                targets[i] = model.predict(state_t)  # Hitting each buttom probability
                Q_sa = model.predict(state_t1)
                
                if terminal:
                    targets[i, action_t] = reward_t
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)
            # targets2 = normalize(targets)
            loss = model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
        else:
#             artificial time delay as training done with this delay
#             loss_df.loc[len(loss_df)] = 0
            time.sleep(0.15)
        s_t = initial_state if terminal else s_t1
        t = t + 1
        
        # save progress every 10000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            
#             model.save_weights("model.h5", overwrite=True)
#             save_obj(D,"D") #saving episodes
#             save_obj(t,"time") #caching time steps
#             save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
#             loss_df.to_csv("./objects/loss_df.csv",index=False)
#             scores_df.to_csv("./objects/scores_df.csv",index=False)
#             actions_df.to_csv("./objects/actions_df.csv",index=False)
#             clear_output()
#             with open("model.json", "w") as outfile:
#                 json.dump(model.to_json(), outfile)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)
    model = buildmodel()
    trainNetwork(model,game_state,observe=observe)

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img()
        self._display.__next__()
    def get_state(self,actions):
#         actions_df.loc[len(actions_df)] = actions[1]
        reward = 0.1
        is_over = False
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen()
        self._display.send(image)

        if self._agent.is_crashed():
            score = self._game.get_score()
#             scores_df.loc[len(loss_df)] = score
            self._game.restart()
            reward = -11/score
            is_over = True
        return image, reward, is_over

# %%
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
import tensorflow as tf
from keras.callbacks import TensorBoard
from collections import deque
import random
import json
# Out:
# Using TensorFlow backend.

# %%
def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
#         cv2.imwrite("screenshot"+str(frame)+".png",screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#searchforplay
playGame(observe=False);
# Out:
# Now we build the model
# We finish building the model
# loop took 0.2456526756286621 seconds
# TIMESTEP 1 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354270935058594 seconds
# TIMESTEP 2 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21607470512390137 seconds
# TIMESTEP 3 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21891570091247559 seconds
# TIMESTEP 4 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21817946434020996 seconds
# TIMESTEP 5 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.22012901306152344 seconds
# TIMESTEP 6 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354270935058594 seconds
# TIMESTEP 7 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253777503967285 seconds
# TIMESTEP 8 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21657538414001465 seconds
# TIMESTEP 9 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.203169584274292 seconds
# TIMESTEP 10 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.21760058403015137 seconds
# TIMESTEP 11 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354223251342773 seconds
# TIMESTEP 12 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354127883911133 seconds
# TIMESTEP 13 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21757912635803223 seconds
# TIMESTEP 14 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354056358337402 seconds
# TIMESTEP 15 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958541870117188 seconds
# TIMESTEP 16 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2185804843902588 seconds
# TIMESTEP 17 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20413637161254883 seconds
# TIMESTEP 18 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20212507247924805 seconds
# TIMESTEP 19 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253944396972656 seconds
# TIMESTEP 20 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21955466270446777 seconds
# TIMESTEP 21 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.4752919673919678 seconds
# TIMESTEP 22 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.39285714285714285 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18146347999572754 seconds
# TIMESTEP 23 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20252704620361328 seconds
# TIMESTEP 24 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21758031845092773 seconds
# TIMESTEP 25 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2035388946533203 seconds
# TIMESTEP 26 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21962428092956543 seconds
# TIMESTEP 27 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21738529205322266 seconds
# TIMESTEP 28 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958422660827637 seconds
# TIMESTEP 29 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.4612255096435547 seconds
# TIMESTEP 30 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1.0 / Q_MAX  0 / Loss  0
# loop took 0.20955991744995117 seconds
# TIMESTEP 31 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354008674621582 seconds
# TIMESTEP 32 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20254015922546387 seconds
# TIMESTEP 33 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21857976913452148 seconds
# TIMESTEP 34 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20554804801940918 seconds
# TIMESTEP 35 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253920555114746 seconds
# TIMESTEP 36 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253825187683105 seconds
# TIMESTEP 37 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21757864952087402 seconds
# TIMESTEP 38 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958589553833008 seconds
# TIMESTEP 39 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.22054147720336914 seconds
# TIMESTEP 40 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2026209831237793 seconds
# TIMESTEP 41 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20153450965881348 seconds
# TIMESTEP 42 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.45922160148620605 seconds
# TIMESTEP 43 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.6470588235294118 / Q_MAX  0 / Loss  0
# loop took 0.21256566047668457 seconds
# TIMESTEP 44 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958374977111816 seconds
# TIMESTEP 45 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20554852485656738 seconds
# TIMESTEP 46 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.20053744316101074 seconds
# TIMESTEP 47 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253300666809082 seconds
# TIMESTEP 48 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20351624488830566 seconds
# TIMESTEP 49 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21747422218322754 seconds
# TIMESTEP 50 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2185831069946289 seconds
# TIMESTEP 51 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2045438289642334 seconds
# TIMESTEP 52 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2005326747894287 seconds
# TIMESTEP 53 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2045438289642334 seconds
# TIMESTEP 54 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.218583345413208 seconds
# TIMESTEP 55 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.44351959228515625 seconds
# TIMESTEP 56 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD -0.6470588235294118 / Q_MAX  0 / Loss  0
# loop took 0.19649457931518555 seconds
# TIMESTEP 57 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20153498649597168 seconds
# TIMESTEP 58 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20655131340026855 seconds
# TIMESTEP 59 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21557331085205078 seconds
# TIMESTEP 60 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958184242248535 seconds
# TIMESTEP 61 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21757888793945312 seconds
# TIMESTEP 62 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20554757118225098 seconds
# TIMESTEP 63 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354342460632324 seconds
# TIMESTEP 64 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253682136535645 seconds
# TIMESTEP 65 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2015373706817627 seconds
# TIMESTEP 66 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21857881546020508 seconds
# TIMESTEP 67 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2185823917388916 seconds
# TIMESTEP 68 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.46022534370422363 seconds
# TIMESTEP 69 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.6470588235294118 / Q_MAX  0 / Loss  0
# loop took 0.21218347549438477 seconds
# TIMESTEP 70 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20296430587768555 seconds
# TIMESTEP 71 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20453715324401855 seconds
# TIMESTEP 72 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21657562255859375 seconds
# TIMESTEP 73 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.17404532432556152 seconds
# TIMESTEP 74 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2016909122467041 seconds
# TIMESTEP 75 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354008674621582 seconds
# TIMESTEP 76 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21757864952087402 seconds
# TIMESTEP 77 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21762824058532715 seconds
# TIMESTEP 78 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18712663650512695 seconds
# TIMESTEP 79 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20331215858459473 seconds
# TIMESTEP 80 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.20357298851013184 seconds
# TIMESTEP 81 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21828770637512207 seconds
# TIMESTEP 82 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958494186401367 seconds
# TIMESTEP 83 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21872711181640625 seconds
# TIMESTEP 84 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18549370765686035 seconds
# TIMESTEP 85 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354151725769043 seconds
# TIMESTEP 86 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253801345825195 seconds
# TIMESTEP 87 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2185814380645752 seconds
# TIMESTEP 88 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.46393656730651855 seconds
# TIMESTEP 89 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.44 / Q_MAX  0 / Loss  0
# loop took 0.2256004810333252 seconds
# TIMESTEP 90 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253872871398926 seconds
# TIMESTEP 91 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253920555114746 seconds
# TIMESTEP 92 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2045457363128662 seconds
# TIMESTEP 93 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21557259559631348 seconds
# TIMESTEP 94 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2188735008239746 seconds
# TIMESTEP 95 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20630121231079102 seconds
# TIMESTEP 96 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2012166976928711 seconds
# TIMESTEP 97 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20098567008972168 seconds
# TIMESTEP 98 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18749761581420898 seconds
# TIMESTEP 99 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21951079368591309 seconds
# TIMESTEP 100 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18759584426879883 seconds
# TIMESTEP 101 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20239472389221191 seconds
# TIMESTEP 102 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.4737424850463867 seconds
# TIMESTEP 103 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.6111111111111112 / Q_MAX  0 / Loss  0
# loop took 0.21356987953186035 seconds
# TIMESTEP 104 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2045438289642334 seconds
# TIMESTEP 105 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2048788070678711 seconds
# TIMESTEP 106 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.19975066184997559 seconds
# TIMESTEP 107 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20267891883850098 seconds
# TIMESTEP 108 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.20253896713256836 seconds
# TIMESTEP 109 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.22058677673339844 seconds
# TIMESTEP 110 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18750357627868652 seconds
# TIMESTEP 111 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20217084884643555 seconds
# TIMESTEP 112 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20250511169433594 seconds
# TIMESTEP 113 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958661079406738 seconds
# TIMESTEP 114 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21757769584655762 seconds
# TIMESTEP 115 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.46390533447265625 seconds
# TIMESTEP 116 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.6470588235294118 / Q_MAX  0 / Loss  0
# loop took 0.22459721565246582 seconds
# TIMESTEP 117 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18649601936340332 seconds
# TIMESTEP 118 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253872871398926 seconds
# TIMESTEP 119 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21757936477661133 seconds
# TIMESTEP 120 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354270935058594 seconds
# TIMESTEP 121 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958374977111816 seconds
# TIMESTEP 122 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253539085388184 seconds
# TIMESTEP 123 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21657586097717285 seconds
# TIMESTEP 124 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354270935058594 seconds
# TIMESTEP 125 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.18749713897705078 seconds
# TIMESTEP 126 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21757888793945312 seconds
# TIMESTEP 127 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2185814380645752 seconds
# TIMESTEP 128 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2045438289642334 seconds
# TIMESTEP 129 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.47283196449279785 seconds
# TIMESTEP 130 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.6111111111111112 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.19750022888183594 seconds
# TIMESTEP 131 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20253872871398926 seconds
# TIMESTEP 132 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.22058677673339844 seconds
# TIMESTEP 133 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.21958398818969727 seconds
# TIMESTEP 134 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354318618774414 seconds
# TIMESTEP 135 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.19952917098999023 seconds
# TIMESTEP 136 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20354127883911133 seconds
# TIMESTEP 137 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.218580961227417 seconds
# TIMESTEP 138 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.218580961227417 seconds
# TIMESTEP 139 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2215900421142578 seconds
# TIMESTEP 140 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.2015383243560791 seconds
# TIMESTEP 141 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# loop took 0.20153474807739258 seconds
# TIMESTEP
