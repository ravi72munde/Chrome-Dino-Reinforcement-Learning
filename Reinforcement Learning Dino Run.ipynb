# %% [markdown]
# ## Reinforcement Learning to play Dino Run
# I used reinfrocement learning to teach the model to control the dino agent from the Chrome's offline game, Dino Run, by detecting and jumping over obstacles. This project is inspired from the DeepMind's paper '[Playing Atari with Deep Reinforcement Learning](https://www.cs.toronto.edu/~vmnih/docs/dqn.pdf)' where the team tranied the model using reinforcement learning to play 7 Atari 2006 games

# %% [markdown]
# ### Modifying the original game for faster learning on CPU only system
# Original game is available as a part of Chromium's open source repository. We can modify the game under the BSD-style license(can be found in repository). Below are the configurations modified as a part of this project<br>
# * ACCELERATION = 0 # speed of the agent stays constant throughout the gameplay
# * TYPES OF OBSTACLES limit to 1, we have trained the model only for a single type of obstacle(cacuts) with fixed size
# * GAME START TIME was reduced to around 400ms, originally each game would take 1 sec to start but reduced for faster learning
# * JUMP VELOCITY was increased because when the dino is mid-air, there are no actions or features to be learned, so stays mid air for shorter period of time
# * GAME OVER PANEL was removed as it is not a feautre to be learned, selenium interface is detect game over and restart
# * HIGH SCORE PANEL was removed as we are not maintaning high score on the game panel
# <br>
#
#
# ### Selnium as interface between the model and game
# As the game is browser based and the model is built on python, we need some interface through which we can observe the game environment and send actions to agent to play the game. We use <strong>Selenium</strong> to control the browser and send actions to the agent.
#
#
# ### OpenCV & PIL for Image capturing and pre-processing
# To acquire the video of game play I have used PIL and openCV to capture & process sequential screenshot from the screen and then fed through the model for traning as well as playing

# %% [markdown]
# #### Imports

# %%
import numpy as np
from PIL import ImageGrab #grabbing image
from PIL import Image
import cv2 #opencv
import io
import time
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (30, 30)
import seaborn as sns
import pandas as pd
import numpy as np
from random import randint
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
import json

# %% [markdown]
# #### Path variables
# We have two external dependencies
# * The modifed version of the game(web app)
# * The executable of chromewebdirve for selenium. This is not included in the repo as it is system dependent, it needs to placed one level above the project folder
# * path to log files

# %%
#path variables
game_url = "game/dino.html"
chrome_driver_path = "../chromedriver.exe"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
scores_file_path = "./objects/scores_df.csv"

# %% [markdown]
# ### Game Module
# This is the main module that implements interfacing between the python and browser-javascript using selenium

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.set_window_size(200, 300)
        self._driver.get(os.path.abspath(game_url))
        #modifying game before trainNetworkining
        if custom_config:
            self._driver.execute_script("Runner.config.ACCELERATION=0")
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
        
        time.sleep(0.25)# no actions are possible 
                        # for 0.25 sec after game starts, 
                        # skip learning at this time and make the model wait
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %% [markdown]
# ### Agent module
# This model represent the agent (Dino) which the model controls for playing.

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
        time.sleep(.5) # no action can be performed for the first time when game starts
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %% [markdown]
# ### Game state module
# Game state helps to get the current state of the game environment as well as the agent.<br>
# Actions are performed by this model before getting a new state

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1*score/10 # dynamic reward calculation
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
            reward = 0.1*score/11
        image = grab_screen() 
        self._display.send(image) #display the image on screen

        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -11/score
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %% [markdown]
# ### Utilities
#
# * save_obj() and load_obj(): As the training can takes a week, we will need to presever the state of the game in the file system. We dump required objects using pickle module of python
# * grab_screen() : using PIL library to capture the screen and bbox for locating the region of interest<sup>+</sup>
# * process_img(): performing necessary image transformations before sending it to the model<sup>+</sup><br>
# * show_img(): coroutine implementation to observe the images that are being sent to the model <sup>*</sup><br>
#
# <sup>+</sup>The image processing modules were inspired from Harrison Sentdex's github which is licensed under the GNU GENERAL PUBLIC LICENSE http://www.gnu.org/licenses/gpl.html<br>
# <sup>*</sup>Coroutine implementation in the code below belongs to Ben Meijering and is licensed under the MIT License https://opensource.org/licenses/MIT

# %%
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)
def grab_screen(_driver = None):
    screen =  np.array(ImageGrab.grab(bbox=(40,180,440,400))) #bbox = region of interset on the entire screen
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    #game is already in grey scale canvas, canny to get only edges and reduce unwanted objects(clouds)
    image = cv2.resize(image, (0,0), fx = 0.15, fy = 0.10) # resale image dimensions
    image = image[2:38,10:50] #img[y:y+h, x:x+w] #crop out the dino agent from the frame
    image = cv2.Canny(image, threshold1 = 100, threshold2 = 200) #apply the canny edge detection
    return  image
def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %% [markdown]
# ### Intialize log structures

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %% [markdown]
# #### Module parameters

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 50000. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 40,20
img_channels = 4 #We stack 4 frames

# %% [markdown]
# ### Building the model
#
# * The input to our model is a tensor: 4 stacked images of dimension of 40x20 = 40x20x4 <br>
# * Each action has it's own output (2 outputs) : The q_value for each action

# %%
view_model = buildmodel()
view_model.summary()
# Out:
# Now we build the model
# We finish building the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 5, 10, 32)         8224
# _________________________________________________________________
# activation_13 (Activation)   (None, 5, 10, 32)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 5, 64)          32832
# _________________________________________________________________
# activation_14 (Activation)   (None, 3, 5, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 5, 64)          36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 3, 5, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               492032
# _________________________________________________________________
# activation_16 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 571,042
# Trainable params: 571,042
# Non-trainable params: 0
# _________________________________________________________________

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), strides=(4, 4), padding='same',input_shape=(img_cols,img_rows,img_channels)))  #20*40*4
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4), strides=(2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    print("We finish building the model")
    return model

# %% [markdown]
# ### Main Training Module
# #### Alogrithm for Deep QNN
#
# ##### The Model code was inspired from the Flappy Bird implementation of reinforcement learning in Pygame.<br>
# #### The original content belongs to [Ben Lau](https://github.com/yanpanlau/Keras-FlappyBird) and is publicly availabe on github
#
# ![image.png](attachment:image.png)

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model_final.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model_final.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[0] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('loop took {} seconds'.format(time.time()-last_time)) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
        else:
            # artificial time delay as training done with this delay
            time.sleep(0.12)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            
            model.save_weights("model_final.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %% [markdown]
# ### main function
# * initialize game module, launches browser
# * initialize the agent module
# * initialize the game state module
# * build the keras model
# * start the training loop

# %%
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# Now we build the model
# We finish building the model
# loop took 1.28102445602417 seconds
# TIMESTEP 1778001 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  5.3213167 / Loss  1.5995183
# loop took 1.6223254203796387 seconds
# TIMESTEP 1778002 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -0.7857142857142857 / Q_MAX  7.0749674 / Loss  0.493844
# loop took 0.22059226036071777 seconds
# TIMESTEP 1778003 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  5.1534233 / Loss  1.6024821
# loop took 0.2356252670288086 seconds
# TIMESTEP 1778004 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  2.9761176 / Loss  3.1948998
# loop took 0.23462295532226562 seconds
# TIMESTEP 1778005 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  2.141553 / Loss  0.33925286
# loop took 0.24866271018981934 seconds
# TIMESTEP 1778006 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  5.6892104 / Loss  1.7370406
# loop took 0.22084450721740723 seconds
# TIMESTEP 1778007 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  5.1771755 / Loss  1.1948988
# loop took 0.24866199493408203 seconds
# TIMESTEP 1778008 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  5.793035 / Loss  1.3531984
# loop took 0.4969947338104248 seconds
# TIMESTEP 1778009 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  5.8236437 / Loss  0.32897067
# loop took 0.24019098281860352 seconds
# TIMESTEP 1778010 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  4.7572083 / Loss  0.6520125
# loop took 0.2333977222442627 seconds
# TIMESTEP 1778011 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  5.2346506 / Loss  0.5276239
# loop took 0.23407483100891113 seconds
# TIMESTEP 1778012 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  5.143293 / Loss  0.8068183
# loop took 0.24865937232971191 seconds
# TIMESTEP 1778013 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  5.3350964 / Loss  1.8637881
# loop took 0.21757721900939941 seconds
# TIMESTEP 1778014 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  5.6148133 / Loss  1.1225555
# loop took 0.23378920555114746 seconds
# TIMESTEP 1778015 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  6.092581 / Loss  0.77620023
# loop took 0.49704504013061523 seconds
# TIMESTEP 1778016 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  5.5577145 / Loss  1.4583614
# loop took 0.23863554000854492 seconds
# TIMESTEP 1778017 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  2.9677038 / Loss  1.5350626
# loop took 0.2330765724182129 seconds
# TIMESTEP 1778018 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  6.279381 / Loss  1.215297
# loop took 0.2355949878692627 seconds
# TIMESTEP 1778019 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  7.329314 / Loss  1.5455333
# loop took 0.24765872955322266 seconds
# TIMESTEP 1778020 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  6.4499764 / Loss  0.29890966
# loop took 0.22020506858825684 seconds
# TIMESTEP 1778021 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  5.0320444 / Loss  1.1140527
# loop took 0.24765706062316895 seconds
# TIMESTEP 1778022 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  4.8182936 / Loss  0.85000503
# loop took 0.4985466003417969 seconds
# TIMESTEP 1778023 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  2.0698445 / Loss  1.9019098
# loop took 0.2373182773590088 seconds
# TIMESTEP 1778024 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  1.5938429 / Loss  0.73438215
# loop took 0.23465847969055176 seconds
# TIMESTEP 1778025 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.04 / Q_MAX  3.522056 / Loss  0.94672847
# loop took 0.2496633529663086 seconds
# TIMESTEP 1778026 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  6.1040516 / Loss  0.24975911
# loop took 0.2195415496826172 seconds
# TIMESTEP 1778027 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  4.501845 / Loss  1.0457014
# loop took 0.23462533950805664 seconds
# TIMESTEP 1778028 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  5.1143694 / Loss  0.63152695
# loop took 0.23268342018127441 seconds
# TIMESTEP 1778029 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  4.7849283 / Loss  0.5034151
# loop took 0.4985997676849365 seconds
# TIMESTEP 1778030 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  2.1449535 / Loss  0.6012678
# loop took 0.2198929786682129 seconds
# TIMESTEP 1778031 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  6.2890334 / Loss  0.93749774
# loop took 0.2204585075378418 seconds
# TIMESTEP 1778032 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.04 / Q_MAX  5.0313864 / Loss  2.1992419
# loop took 0.2486588954925537 seconds
# TIMESTEP 1778033 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  3.8185444 / Loss  0.5716084
# loop took 0.23421382904052734 seconds
# TIMESTEP 1778034 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  4.6671286 / Loss  1.4578857
# loop took 0.24863290786743164 seconds
# TIMESTEP 1778035 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  5.9922547 / Loss  1.3346392
# loop took 0.41109323501586914 seconds
# TIMESTEP 1778036 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  5.17261 / Loss  0.8183059
# loop took 0.2310953140258789 seconds
# TIMESTEP 1778037 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.10909090909090911 / Q_MAX  6.4566894 / Loss  0.7735766
# loop took 0.23261809349060059 seconds
# TIMESTEP 1778038 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1272727272727273 / Q_MAX  5.4134283 / Loss  0.4476931
# loop took 0.23434877395629883 seconds
# TIMESTEP 1778039 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.13636363636363635 / Q_MAX  4.8810806 / Loss  2.4006562
# loop took 0.21958470344543457 seconds
# TIMESTEP 1778040 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.16 / Q_MAX  4.3330574 / Loss  0.7855799
# loop took 0.23462390899658203 seconds
# TIMESTEP 1778041 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.16363636363636364 / Q_MAX  2.8952847 / Loss  0.4678185
# loop took 0.21663570404052734 seconds
# TIMESTEP 1778042 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.19 / Q_MAX  4.2605944 / Loss  0.40761095
# loop took 0.25066614151000977 seconds
# TIMESTEP 1778043 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.18181818181818182 / Q_MAX  3.6287181 / Loss  0.455831
# loop took 0.21863222122192383 seconds
# TIMESTEP 1778044 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.22000000000000003 / Q_MAX  5.158413 / Loss  0.88580084
# loop took 0.24866080284118652 seconds
# TIMESTEP 1778045 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.2090909090909091 / Q_MAX  5.8014846 / Loss  0.5719334
# loop took 0.4966294765472412 seconds
# TIMESTEP 1778046 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -0.4583333333333333 / Q_MAX  4.3611884 / Loss  1.484654
# loop took 0.2106029987335205 seconds
# TIMESTEP 1778047 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.018181818181818184 / Q_MAX  2.5344176 / Loss  1.7830293
# loop took 0.24866056442260742 seconds
# TIMESTEP 1778048 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  5.32563 / Loss  1.1715951
# loop took 0.24866056442260742 seconds
# TIMESTEP 1778049 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  4.092524 / Loss  0.97980475
# loop took 0.24866056442260742 seconds
# TIMESTEP 1778050 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  4.7917495 / Loss  0.8168639
# loop took 0.21738719940185547 seconds
# TIMESTEP 1778051 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  5.350728 / Loss  0.753822
# loop took 0.2179551124572754 seconds
# TIMESTEP 1778052 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  4.3489428 / Loss  0.31170136
# loop took 0.5149154663085938 seconds
# TIMESTEP 1778053 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  5.3647156 / Loss  0.8635604
# loop took 0.2200908660888672 seconds
# TIMESTEP 1778054 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  3.9559894 / Loss  1.2713467
# loop took 0.23372888565063477 seconds
# TIMESTEP 1778055 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  3.630672 / Loss  0.9296876
# loop took 0.24866008758544922 seconds
# TIMESTEP 1778056 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  4.32333 / Loss  0.9679563
# loop took 0.21960711479187012 seconds
# TIMESTEP 1778057 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  2.944444 / Loss  1.0347004
# loop took 0.2487037181854248 seconds
# TIMESTEP 1778058 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  5.7661963 / Loss  0.23738638
# loop took 0.23594927787780762 seconds
# TIMESTEP 1778059 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  4.922413 / Loss  1.1665615
# loop took 0.49799299240112305 seconds
# TIMESTEP 1778060 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  5.6891117 / Loss  0.503747
# loop took 0.2366960048675537 seconds
# TIMESTEP 1778061 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  4.2446833 / Loss  0.83575857
# loop took 0.20551466941833496 seconds
# TIMESTEP 1778062 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.04 / Q_MAX  2.7251062 / Loss  0.62414
# loop took 0.2333223819732666 seconds
# TIMESTEP 1778063 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  5.345372 / Loss  0.8995943
# loop took 0.2340998649597168 seconds
# TIMESTEP 1778064 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.6951866 / Loss  1.4362196
# loop took 0.23161554336547852 seconds
# TIMESTEP 1778065 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  5.3261657 / Loss  0.5439833
# loop took 0.23648333549499512 seconds
# TIMESTEP 1778066 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.08181818181818182 / Q_MAX  4.7742066 / Loss  1.0312679
# loop took 0.2332613468170166 seconds
# TIMESTEP 1778067 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  5.493355 / Loss  1.0492967
# loop took 0.23462390899658203 seconds
# TIMESTEP 1778068 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.10909090909090911 / Q_MAX  4.0739613 / Loss  0.85168874
# loop took 0.21925663948059082 seconds
# TIMESTEP 1778069 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.14 / Q_MAX  5.6576695 / Loss  2.109923
# loop took 0.23343420028686523 seconds
# TIMESTEP 1778070 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.13636363636363635 / Q_MAX  4.085989 / Loss  2.1900077
# loop took 0.23590302467346191 seconds
# TIMESTEP 1778071 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.14545454545454548 / Q_MAX  5.0873246 / Loss  1.3848342
# loop took 0.23412632942199707 seconds
# TIMESTEP 1778072 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.16363636363636364 / Q_MAX  3.91537 / Loss  1.7606189
# loop took 0.20620465278625488 seconds
# TIMESTEP 1778073 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.19 / Q_MAX  5.1459913 / Loss  0.8601155
# loop took 0.23057126998901367 seconds
# TIMESTEP 1778074 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.2 / Q_MAX  5.517831 / Loss  0.5400169
# loop took 0.2188587188720703 seconds
# TIMESTEP 1778075 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.2 / Q_MAX  2.4159713 / Loss  1.1628989
# loop took 0.23395133018493652 seconds
# TIMESTEP 1778076 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.2090909090909091 / Q_MAX  2.9396582 / Loss  0.74300075
# loop took 0.2325890064239502 seconds
# TIMESTEP 1778077 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.22727272727272727 / Q_MAX  3.9260068 / Loss  1.3596784
# loop took 0.23665881156921387 seconds
# TIMESTEP 1778078 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.23636363636363636 / Q_MAX  3.908132 / Loss  1.0821079
# loop took 0.23410296440124512 seconds
# TIMESTEP 1778079 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.24545454545454548 / Q_MAX  4.387831 / Loss  0.4079809
# loop took 0.2334597110748291 seconds
# TIMESTEP 1778080 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.26363636363636367 / Q_MAX  6.007677 / Loss  1.5417559
# loop took 0.49886512756347656 seconds
# TIMESTEP 1778081 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -0.3793103448275862 / Q_MAX  3.7595975 / Loss  1.394702
# loop took 0.45320820808410645 seconds
# TIMESTEP 1778082 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  2.7938948 / Loss  1.0326729
# loop took 0.24947786331176758 seconds
# TIMESTEP 1778083 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  3.9002843 / Loss  0.41032106
# loop took 0.22265076637268066 seconds
# TIMESTEP 1778084 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.7661748 / Loss  1.3457637
# loop took 0.21657395362854004 seconds
# TIMESTEP 1778085 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  2.0184898 / Loss  0.9129848
# loop took 0.21824312210083008 seconds
# TIMESTEP 1778086 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.08181818181818182 / Q_MAX  4.7781568 / Loss  1.6391342
# loop took 0.23462438583374023 seconds
# TIMESTEP 1778087 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  4.131903 / Loss  0.8728378
# loop took 0.2185819149017334 seconds
# TIMESTEP 1778088 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.10909090909090911 / Q_MAX  4.3859386 / Loss  0.7804987
# loop took 0.48529577255249023 seconds
# TIMESTEP 1778089 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -0.9166666666666666 / Q_MAX  3.704245 / Loss  1.0381843
# loop took 0.21943902969360352 seconds
# TIMESTEP 1778090 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.030000000000000006 / Q_MAX  1.458005 / Loss  0.34911853
# loop took 0.24866008758544922 seconds
# TIMESTEP 1778091 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  6.309973 / Loss  0.25664392
# loop took 0.23382234573364258 seconds
# TIMESTEP 1778092 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  5.8537817 / Loss  0.93636084
# loop took 0.23416614532470703 seconds
# TIMESTEP 1778093 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.6573884 / Loss  0.23474348
# loop took 0.20354318618774414 seconds
# TIMESTEP 1778094 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  3.5537453 / Loss  0.38647515
# loop took 0.23398590087890625 seconds
# TIMESTEP 1778095 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.08181818181818182 / Q_MAX  2.1415005 / Loss  0.7126639
# loop took 0.23377513885498047 seconds
# TIMESTEP 1778096 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  4.8359356 / Loss  1.1730347
# loop took 0.23427581787109375 seconds
# TIMESTEP 1778097 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.10909090909090911 / Q_MAX  4.617776 / Loss  0.8455734
# loop took 0.28174853324890137 seconds
# TIMESTEP 1778098 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1272727272727273 / Q_MAX  4.4613676 / Loss  0.28577632
# loop took 0.21744561195373535 seconds
# TIMESTEP 1778099 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.15 / Q_MAX  5.807186 / Loss  0.69331884
# loop took 0.23689627647399902 seconds
# TIMESTEP 1778100 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.15454545454545457 / Q_MAX  4.5605345 / Loss  1.349064
# loop took 0.5118556022644043 seconds
# TIMESTEP 1778101 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -0.6111111111111112 / Q_MAX  4.771369 / Loss  0.8950945
# loop took 0.22110271453857422 seconds
# TIMESTEP 1778102 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  4.0190563 / Loss  0.16681829
# loop took 0.23311519622802734 seconds
# TIMESTEP 1778103 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  3.5463412 / Loss  0.51690865
# loop took 0.23662996292114258 seconds
# TIMESTEP 1778104 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  0.68922234 / Loss  0.32321113
# loop took 0.23243403434753418 seconds
# TIMESTEP 1778105 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  5.456935 / Loss  0.946021
# loop took 0.2657051086425781 seconds
# TIMESTEP 1778106 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  5.4032354 / Loss  0.3752117
# loop took 0.22013545036315918 seconds
# TIMESTEP 1778107 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  5.303833 / Loss  1.10869
# loop took 0.51348876953125 seconds
# TIMESTEP 1778108 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  5.101226 / Loss  1.0868285
# loop took 0.23640942573547363 seconds
# TIMESTEP 1778109 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  3.8160388 / Loss  0.55943865
# loop took 0.2349238395690918 seconds
# TIMESTEP 1778110 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  3.9746413 / Loss  0.98527735
# loop took 0.21981430053710938 seconds
# TIMESTEP 1778111 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  4.380708 / Loss  0.98430485
# loop took 0.24765753746032715 seconds
# TIMESTEP 1778112 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  2.640949 / Loss  0.7961099
# loop took 0.2166435718536377 seconds
# TIMESTEP 1778113 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  2.9129944 / Loss  0.30661726
# loop took 0.23651480674743652 seconds
# TIMESTEP 1778114 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  4.5450444 / Loss  0.43059403
# loop took 0.23436903953552246 seconds
# TIMESTEP 1778115 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  3.542822 / Loss  0.58216095
# loop took 0.2170734405517578 seconds
# TIMESTEP 1778116 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.12000000000000002 / Q_MAX  5.7547607 / Loss  0.26673406
# loop took 0.2366952896118164 seconds
# TIMESTEP 1778117 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1272727272727273 / Q_MAX  4.4679103 / Loss  0.75432867
# loop took 0.21761155128479004 seconds
# TIMESTEP 1778118 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.15 / Q_MAX  2.8922153 / Loss  1.198966
# loop took 0.2209467887878418 seconds
# TIMESTEP 1778119 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.16 / Q_MAX  4.2477217 / Loss  0.6665385
# loop took 0.23562407493591309 seconds
# TIMESTEP 1778120 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.16363636363636364 / Q_MAX  1.0622711 / Loss  0.8244517
# loop took 0.23309755325317383 seconds
# TIMESTEP 1778121 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.17272727272727273 / Q_MAX  3.7341452 / Loss  0.664935
# loop took 0.23300552368164062 seconds
# TIMESTEP 1778122 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.19090909090909092 / Q_MAX  1.6434093 / Loss  0.47469062
# loop took 0.23407411575317383 seconds
# TIMESTEP 1778123 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.2 / Q_MAX  4.2808948 / Loss  0.731169
# loop took 0.21757745742797852 seconds
# TIMESTEP 1778124 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.23000000000000004 / Q_MAX  5.9055967 / Loss  0.8608056
# loop took 0.23363590240478516 seconds
# TIMESTEP 1778125 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.22727272727272727 / Q_MAX  5.1331787 / Loss  0.1718213
# loop took 0.49869847297668457 seconds
# TIMESTEP 1778126 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -0.4230769230769231 / Q_MAX  4.504838 / Loss  0.8774806
# loop took 0.22187018394470215 seconds
# TIMESTEP 1778127 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  4.9739547 / Loss  0.8120805
# loop took 0.23261618614196777 seconds
# TIMESTEP 1778128 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  4.869474 / Loss  1.1716492
# loop took 0.46924591064453125 seconds
# TIMESTEP 1778129 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  4.9554043 / Loss  0.342161
# loop took 0.20554757118225098 seconds
# TIMESTEP 1778130 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  5.77682 / Loss  0.5970159
# loop took 0.2496650218963623 seconds
# TIMESTEP 1778131 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.08181818181818182 / Q_MAX  4.5310445 / Loss  0.6533431
# loop took 0.4938085079193115 seconds
# TIMESTEP 1778132 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  4.259 / Loss  0.7480818
# loop took 0.2224442958831787 seconds
# TIMESTEP 1778133 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  4.3418818 / Loss  0.31825542
# loop took 0.23349404335021973 seconds
# TIMESTEP 1778134 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  3.429028 / Loss  1.024392
# loop took 0.23371410369873047 seconds
# TIMESTEP 1778135 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  5.5183115 / Loss  0.23978266
# loop took 0.2362508773803711 seconds
# TIMESTEP 1778136 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  4.583108 / Loss  1.6630167
# loop took 0.23448586463928223 seconds
# TIMESTEP 1778137 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  3.4248548 / Loss  1.3340957
# loop took 0.23195981979370117 seconds
# TIMESTEP 1778138 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  4.151571 / Loss  1.0510404
# loop took 0.4977872371673584 seconds
# TIMESTEP 1778139 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  1.3332484 / Loss  0.5668551
# loop took 0.22154664993286133 seconds
# TIMESTEP 1778140 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  2.741909 / Loss  0.8519292
# loop took 0.23564362525939941 seconds
# TIMESTEP 1778141 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  3.798545 / Loss  1.0688013
# loop took 0.26470184326171875 seconds
# TIMESTEP 1778142 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  5.7853656 / Loss  0.3240019
# loop took 0.23362326622009277 seconds
# TIMESTEP 1778143 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.6906102 / Loss  0.3146441
# loop took 0.23362016677856445 seconds
# TIMESTEP 1778144 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  4.2552485 / Loss  0.59100646
# loop took 0.25166916847229004 seconds
# TIMESTEP 1778145 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  2.0361862 / Loss  0.86341286
# loop took 0.49659061431884766 seconds
# TIMESTEP 1778146 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  3.5346546 / Loss  0.41193646
# loop took 0.2214665412902832 seconds
# TIMESTEP 1778147 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  2.6556845 / Loss  1.6253473
# loop took 0.21693754196166992 seconds
# TIMESTEP 1778148 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.04 / Q_MAX  3.368812 / Loss  1.0186759
# loop took 0.2356259822845459 seconds
# TIMESTEP 1778149 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  3.5516388 / Loss  0.46739152
# loop took 0.2506678104400635 seconds
# TIMESTEP 1778150 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.327713 / Loss  0.6065005
# loop took 0.24866056442260742 seconds
# TIMESTEP 1778151 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  5.1922054 / Loss  0.81829834
# loop took 0.21718049049377441 seconds
# TIMESTEP 1778152 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.09090909090909091 / Q_MAX  5.6741385 / Loss  0.63685054
# loop took 0.48284101486206055 seconds
# TIMESTEP 1778153 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD -1.0 / Q_MAX  4.929192 / Loss  0.31528002
# loop took 0.23731040954589844 seconds
# TIMESTEP 1778154 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.018181818181818184 / Q_MAX  3.4421659 / Loss  1.3591976
# loop took 0.2185814380645752 seconds
# TIMESTEP 1778155 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.04 / Q_MAX  4.8858643 / Loss  1.5774279
# loop took 0.23361945152282715 seconds
# TIMESTEP 1778156 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  4.237423 / Loss  0.8599193
# loop took 0.24994659423828125 seconds
# TIMESTEP 1778157 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.9543538 / Loss  1.0462283
# loop took 0.21871662139892578 seconds
# TIMESTEP 1778158 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  4.5279818 / Loss  0.38072312
# loop took 0.234375 seconds
# TIMESTEP 1778159 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.08181818181818182 / Q_MAX  2.1658192 / Loss  0.396855
# loop took 0.49767398834228516 seconds
# TIMESTEP 1778160 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1.0 / Q_MAX  5.309417 / Loss  0.9102574
# loop took 0.21888327598571777 seconds
# TIMESTEP 1778161 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  3.4647603 / Loss  0.65203106
# loop took 0.21650075912475586 seconds
# TIMESTEP 1778162 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.04 / Q_MAX  4.5170035 / Loss  1.1137528
# loop took 0.2346324920654297 seconds
# TIMESTEP 1778163 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  2.1263704 / Loss  0.582934
# loop took 0.25167036056518555 seconds
# TIMESTEP 1778164 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.3013585 / Loss  1.363953
# loop took 0.21861743927001953 seconds
# TIMESTEP 1778165 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.07272727272727274 / Q_MAX  1.2176291 / Loss  0.604326
# loop took 0.23173165321350098 seconds
# TIMESTEP 1778166 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.08181818181818182 / Q_MAX  4.254526 / Loss  0.58162576
# loop took 0.2362971305847168 seconds
# TIMESTEP 1778167 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  4.4358773 / Loss  0.5037569
# loop took 0.23450732231140137 seconds
# TIMESTEP 1778168 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.10909090909090911 / Q_MAX  1.4750161 / Loss  0.37181544
# loop took 0.23590731620788574 seconds
# TIMESTEP 1778169 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1272727272727273 / Q_MAX  5.015521 / Loss  0.5793811
# loop took 0.20055651664733887 seconds
# TIMESTEP 1778170 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.15 / Q_MAX  3.9324477 / Loss  0.7280924
# loop took 0.23398137092590332 seconds
# TIMESTEP 1778171 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.14545454545454548 / Q_MAX  3.3041387 / Loss  0.5567345
# loop took 0.21703004837036133 seconds
# TIMESTEP 1778172 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.18 / Q_MAX  1.653617 / Loss  1.3845359
# loop took 0.23604369163513184 seconds
# TIMESTEP 1778173 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.17272727272727273 / Q_MAX  4.3029943 / Loss  0.36710232
# loop took 0.23502135276794434 seconds
# TIMESTEP 1778174 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.18181818181818182 / Q_MAX  3.3077178 / Loss  0.34824365
# loop took 0.2173933982849121 seconds
# TIMESTEP 1778175 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.22000000000000003 / Q_MAX  4.9597235 / Loss  0.27092913
# loop took 0.42313647270202637 seconds
# TIMESTEP 1778176 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.24000000000000005 / Q_MAX  4.2952075 / Loss  0.18588214
# loop took 0.49379420280456543 seconds
# TIMESTEP 1778177 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -0.44 / Q_MAX  4.7255793 / Loss  0.35244787
# loop took 0.22560453414916992 seconds
# TIMESTEP 1778178 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.02727272727272728 / Q_MAX  3.7160711 / Loss  0.6081024
# loop took 0.23336148262023926 seconds
# TIMESTEP 1778179 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.03636363636363637 / Q_MAX  5.676816 / Loss  0.6475884
# loop took 0.23450779914855957 seconds
# TIMESTEP 1778180 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.045454545454545456 / Q_MAX  5.6043034 / Loss  0.46893573
# loop took 0.21774840354919434 seconds
# TIMESTEP 1778181 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.06363636363636364 / Q_MAX  3.7319055 / Loss  0.5265401
# loop took 0.22058677673339844 seconds
# TIMESTEP 1778182 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.08 / Q_MAX  3.032987 / Loss  0.6034565
# loop took 0.2496631145477295 seconds
# TIMESTEP 1778183 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.08181818181818182 / Q_MAX  4.819603 / Loss  0.26879248
# loop took 0.23462390899658203 seconds
# TIMESTEP 1778184 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  4.850174 / Loss  1.0365465
# loop took 0.21594929695129395 seconds
# TIMESTEP 1778185 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.12000000000000002 / Q_MAX  3.240161 / Loss  0.43882483

# %% [markdown]
# ### Plotting the game training logs

# %%
# %matplotlib inline 
def show_plots():
    fig, axs = plt.subplots(ncols=1,nrows =3,figsize=(15,15))
    loss_df = pd.read_csv("./objects/loss_df.csv").clip(0,50)
    scores_df = pd.read_csv("./objects/scores_df.csv").clip(11,150)
    actions_df = pd.read_csv("./objects/actions_df.csv")
    loss_df['loss'] = loss_df['loss'].astype('float') 
    loss_df.plot(use_index=True,ax=axs[0])
    scores_df.plot(ax=axs[1])
    sns.distplot(actions_df,ax=axs[2])
    imgg = fig.canvas.draw()
show_plots()
# Out:
# C:\Users\ravi7\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
