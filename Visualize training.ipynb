# %%
import time
# %matplotlib inline 
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (15, 9)
import seaborn as sns
import pandas as pd
import numpy as np

# %%
def show_plots(realtime = True,t=0):
    fig, axs = plt.subplots(ncols=2,nrows =2)
    loss_df = pd.read_csv("./objects/loss_df.csv").tail(2000)
    scores_df = pd.read_csv("./objects/scores_df.csv")
    actions_df = pd.read_csv("./objects/actions_df.csv")
    q_max_df = pd.read_csv("./objects/q_values.csv")
    loss_df['loss'] = loss_df['loss'].astype('float') 
    loss_df.plot(use_index=True,ax=axs[0,0])
    scores_df.plot(ax=axs[0,1])
    sns.distplot(actions_df,ax=axs[1,0])
#     q_max_df.plot(ax = axs[1,1])
    imgg = fig.canvas.draw()
    graph_img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
    graph_img = graph_img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#     disp = show_img(graphs=True)
#     disp.__next__()
    cv2.imwrite("logs/progress/pg"+str(t)+".png",graph_img) if realtime else 0

# %%
show_plots(realtime=False)
# Out:
# C:\Users\ravi7\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
import pandas as pd
scores_df = pd.read_csv("./objects/scores_df.csv")

# %%
scores_df.tail(1000).mean()
# Out:
# scores    29.2
# dtype: float64

# %%
scores_df.query('scores >60')
# Out:
#         scores
# 35291       85
# 35335       67
# 35339       71
# 36078       84
# 40994       61
# 63415       67
# 63433       67
# 71244       81
# 72902       76
# 78302       73
# 81932       66
# 121882      66
# 122576      61
# 123170      66
# 124038      66
# 125311      70
# 127196      79
# 128337      64
# 128509      77
# 128888      63
# 129313      66
# 129316      61
# 129773      66
# 130530      76
# 134597      67
# 134623      61
# 134750      61
# 135380      68
# 135917      66
# 136246      82
# ...        ...
# 195390      81
# 195404      76
# 195415      69
# 195428      67
# 195429      71
# 195433     100
# 195437      86
# 195443      64
# 195452      73
# 195464      91
# 195465      95
# 195486      89
# 195490      99
# 195492      74
# 195493      77
# 195502     145
# 195510      64
# 195518      72
# 195529      75
# 195530     113
# 195531      85
# 195534     125
# 195544      86
# 195549      76
# 195565      64
# 195567     177
# 195569     107
# 195573      74
# 195583     128
# 195617      72
#
# [2110 rows x 1 columns]

# %%
interval = 1000
for x in range(int(len(scores_df)/1000)):
    print(scores_df.head(interval).max())
    interval+=1000
# Out:
# scores    34
# dtype: int64
# scores    34
# dtype: int64
# scores    39
# dtype: int64
# scores    45
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    88
# dtype: int64
# scores    88
# dtype: int64
# scores    94
# dtype: int64
# scores    94
# dtype: int64
# scores    96
# dtype: int64
# scores    131
# dtype: int64
# scores    131
# dtype: int64
# scores    131
# dtype: int64
# scores    131
# dtype: int64
# scores    132
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
# scores    265
# dtype: int64
