# %%
import time
# %matplotlib inline 
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (15, 9)
import seaborn as sns
import pandas as pd
import numpy as np

# %%
def show_plots(realtime = True,t=0):
    fig, axs = plt.subplots(ncols=2,nrows =2)
    loss_df = pd.read_csv("./objects/loss_df.csv").tail(20000)
    scores_df = pd.read_csv("./objects/scores_df.csv").tail(20000)
    actions_df = pd.read_csv("./objects/actions_df.csv").tail(20000)
    q_max_df = pd.read_csv("./objects/q_values.csv")
    loss_df['loss'] = loss_df['loss'].astype('float') 
    loss_df.plot(use_index=True,ax=axs[0,0])
    scores_df.plot(ax=axs[0,1])
    sns.distplot(actions_df,ax=axs[1,0])
    q_max_df.plot(ax = axs[1,1])
    imgg = fig.canvas.draw()
    graph_img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
    graph_img = graph_img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#     disp = show_img(graphs=True)
#     disp.__next__()
    cv2.imwrite("logs/progress/pg"+str(t)+".png",graph_img) if realtime else 0

# %%
show_plots(realtime=False)
# Out:
# C:\Users\ravi7\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\ravi7\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3124: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))

# %%
scores_df = pd.read_csv("./objects/scores_df.csv")

# %%
scores_df.tail(1000).mean()
# Out:
# scores    24.71
# dtype: float64

# %%
interval = 1000
for x in range(int(len(scores_df)/1000)):
    print(scores_df.head(interval).max())
    interval+=1000
# Out:
# scores    34
# dtype: int64
# scores    34
# dtype: int64
# scores    39
# dtype: int64
# scores    45
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    54
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    85
# dtype: int64
# scores    88
# dtype: int64
# scores    88
# dtype: int64
# scores    94
# dtype: int64
# scores    94
# dtype: int64
# scores    96
# dtype: int64
# scores    131
# dtype: int64
# scores    131
# dtype: int64
# scores    131
# dtype: int64
# scores    131
# dtype: int64
# scores    132
# dtype: int64
